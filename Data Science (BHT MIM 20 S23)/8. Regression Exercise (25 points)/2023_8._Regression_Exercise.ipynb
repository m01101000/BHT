# %%
# import dependencies and load data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor


# load fish data
url = "https://raw.githubusercontent.com/WHPAN0108/BHT-DataScience-S23/main/regression/data/Fish.csv"
fish_data = pd.read_csv(url)
print(fish_data)
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
# 1. Randomly split dataset with 70/30 training and test dataset

# Split the dataset into features (X) and target variable (y)
X = fish_data[['Length1', 'Length2', 'Length3', 'Height', 'Width']]
y = fish_data['Weight']

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print("Test Data = ",X_train.shape)
print("Train Data = ",X_test.shape)
print("Target Train = ",y_train.shape)
print("Target Test = ",y_test.shape)
# Out:
# Test Data =  (111, 5)
# Train Data =  (48, 5)
# Target Train =  (111,)
# Target Test =  (48,)

# %%
# 2. Use linear regression and 3. calculate RMSE and R2 in the test set

# Create an instance of the Linear Regression model
linear_reg = LinearRegression()

# Fit the model on the training data
linear_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred_linear = linear_reg.predict(X_test)

# Calculate RMSE and R2 score
rmse_linear = np.sqrt(mean_squared_error(y_test, y_pred_linear))
r2_linear = r2_score(y_test, y_pred_linear)

print('Linear Regression:')
print('RMSE:', rmse_linear)
print('R2 Score:', r2_linear)
# Out:
# Linear Regression:
# RMSE: 127.34844881001277
# R2 Score: 0.8676045498644964

# %%
# 2. Use random forest model and 3. calculate RMSE and R2 in the test set

# Create an instance of the Random Forest model
rf_reg = RandomForestRegressor(random_state=42)

# Fit the model on the training data
rf_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred_rf = rf_reg.predict(X_test)

# Calculate RMSE and R2 score
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))
r2_rf = r2_score(y_test, y_pred_rf)

print('Random Forest:')
print('RMSE:', rmse_rf)
print('R2 Score:', r2_rf)
# Out:
# Random Forest:
# RMSE: 58.07187691363639
# R2 Score: 0.9724692864561703

# %%
# 4. Visualized the predictions and compare the method (y_pred vs y_test)

plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred_linear, color='blue', label='Linear Regression')
plt.scatter(y_test, y_pred_rf, color='red', label='Random Forest')
plt.xlabel('Actual Weight')
plt.ylabel('Predicted Weight')
plt.title('Actual vs. Predicted Weight')
plt.legend()
plt.show()

# %%
# 5. Change the training-test split setting, with the 70/30 principle for each species.
# That means, in any of the species, there needs to be 70% of the sample in the training set, and 30% of the sample in the test set.
# &
# 6. Redo step 2,3,4 in Task1

# load fish data
url = "https://raw.githubusercontent.com/WHPAN0108/BHT-DataScience-S23/main/regression/data/Fish.csv"
fish_data = pd.read_csv(url)

# Get unique species
species = fish_data["Species"].unique()
print(species)
print("------------------------------------------------------")

# Iterate over each species
for specie in species:
    print("Species:", specie)
    
    # Filter data for the current species
    specie_data = fish_data[fish_data["Species"] == specie]

    # Split the dataset into features (X) and target variable (y)
    X = specie_data[['Length1', 'Length2', 'Length3', 'Height', 'Width']]
    y = specie_data['Weight']

    # Split the dataset into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    print("Train Data:", X_train.shape)
    print("Test Data:", X_test.shape)
    print("Target Train:", y_train.shape)
    print("Target Test:", y_test.shape)

    # Create an instance of the Linear Regression model
    linear_reg = LinearRegression()

    # Fit the model on the training data
    linear_reg.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_linear = linear_reg.predict(X_test)

    # Calculate RMSE and R2 score for linear regression
    rmse_linear = np.sqrt(mean_squared_error(y_test, y_pred_linear))
    r2_linear = r2_score(y_test, y_pred_linear)

    print('Linear Regression:')
    print('RMSE:', rmse_linear)
    print('R2 Score:', r2_linear)

    # Create an instance of the Random Forest model
    rf_reg = RandomForestRegressor(random_state=42)

    # Fit the model on the training data
    rf_reg.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_rf = rf_reg.predict(X_test)

    # Calculate RMSE and R2 score for random forest
    rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))
    r2_rf = r2_score(y_test, y_pred_rf)

    print('Random Forest:')
    print('RMSE:', rmse_rf)
    print('R2 Score:', r2_rf)

    # Visualize the predictions for linear regression and random forest
    plt.figure(figsize=(10, 6))
    plt.scatter(y_test, y_pred_linear, color='blue', label='Linear Regression')
    plt.scatter(y_test, y_pred_rf, color='red', label='Random Forest')
    plt.xlabel('Actual Weight')
    plt.ylabel('Predicted Weight')
    plt.title('Actual vs. Predicted Weight')
    plt.legend()
    plt.show()

    print("------------------------------------------------------")
# Out:
# ['Bream' 'Roach' 'Whitefish' 'Parkki' 'Perch' 'Pike' 'Smelt']
# ------------------------------------------------------
# Species: Bream
# Train Data: (24, 5)
# Test Data: (11, 5)
# Target Train: (24,)
# Target Test: (11,)
# Linear Regression:
# RMSE: 69.50043033725245
# R2 Score: 0.8279181239633567
# Random Forest:
# RMSE: 86.21005794516721
# R2 Score: 0.7352255840657158
# ------------------------------------------------------
# Species: Roach
# Train Data: (14, 5)
# Test Data: (6, 5)
# Target Train: (14,)
# Target Test: (6,)
# Linear Regression:
# RMSE: 60.304049156849594
# R2 Score: 0.6330446641076832
# Random Forest:
# RMSE: 60.05497578608009
# R2 Score: 0.6360696699508079
# ------------------------------------------------------
# Species: Whitefish
# Train Data: (4, 5)
# Test Data: (2, 5)
# Target Train: (4,)
# Target Test: (2,)
# Linear Regression:
# RMSE: 76.37654493689855
# R2 Score: 0.0
# Random Forest:
# RMSE: 149.98000000000002
# R2 Score: 0.0
# ------------------------------------------------------
# Species: Parkki
# Train Data: (7, 5)
# Test Data: (4, 5)
# Target Train: (7,)
# Target Test: (4,)
# Linear Regression:
# RMSE: 48.92290938583195
# R2 Score: 0.7588340911104515
# Random Forest:
# RMSE: 73.31227301755143
# R2 Score: 0.4584423018791879
# ------------------------------------------------------
# Species: Perch
# Train Data: (39, 5)
# Test Data: (17, 5)
# Target Train: (39,)
# Target Test: (17,)
# Linear Regression:
# RMSE: 108.14052279595845
# R2 Score: 0.8704515818466942
# Random Forest:
# RMSE: 42.87176816836872
# R2 Score: 0.9796390528822491
# ------------------------------------------------------
# Species: Pike
# Train Data: (11, 5)
# Test Data: (6, 5)
# Target Train: (11,)
# Target Test: (6,)
# Linear Regression:
# RMSE: 171.50254117897325
# R2 Score: 0.912643842260608
# Random Forest:
# RMSE: 208.85095909922623
# R2 Score: 0.8704535987443617
# ------------------------------------------------------
# Species: Smelt
# Train Data: (9, 5)
# Test Data: (5, 5)
# Target Train: (9,)
# Target Test: (5,)
# Linear Regression:
# RMSE: 1.4391032923031377
# R2 Score: 0.8946582764029639
# Random Forest:
# RMSE: 1.4932277790076018
# R2 Score: 0.8865854933875903
# ------------------------------------------------------
